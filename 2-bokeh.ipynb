# %% [markdown]
# Introduction to Bokeh
# =====================
#
# In this tutorial we'll learn how to use Bokeh to build interactive visualizations viewable in a browser.  Generally this tutorial will have the following format
#
# `plotting` - Intermediate interface allowing control to all parts of a plot
#     - Vectorized attributes
#     - Toolbars
#     - Linked Brushing
#     - Interactivity
#
# Install
# -------
#
# This tutorial uses many different libraries that are all available with the [Anaconda Distribution](http://continuum.io/downloads). Once you have Anaconda install, please run these commands from a terminal:
#
# ```
# $ conda install -y bokeh
# ```
#
#
# <hr/>

# %% [markdown]
# # Introduction to [Bokeh](http://bokeh.pydata.org/)
#
# Provide a first-class visualization library for web-aware applications, without
# requiring web-level programming.
#
# Write a visualization python. Bokeh creates data descripors and a scenegraph consumed by BokehJS.
# This works in ipython notebook, creating static files and interacting with dynamic data sources.
#
# Bokeh includes pre-built schemas in bokeh.charts, a low-level composition interface (similar to matplotlib),
# a server for large and/or dynamic datasources and widgets for providing client-side realtime interaction.
#
# The non-JS framework also has prototypes in other languages (Scala, Julia...maybe R).
#
# **Note:** There are examples notebooks in bokeh/examples/plotting/notebooks. Start an ipython notebook server there to get more examples.
#
# [Gallery](http://bokeh.pydata.org/docs/gallery.html) --
# [tutorial](http://bokeh.pydata.org/tutorial/index.html) --
# [Documentation](http://bokeh.pydata.org/docs/user_guide.html) --
# [Repo](https://github.com/bokeh/bokeh)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Output
#
# Bokeh can output to html, a notebook, or just fragments for embedding in a web application.
#
# To start playing, we'll use the notebook. Later we will see the other types of output.

# %%
from bokeh.plotting import output_notebook  
output_notebook() # Tell Bokeh to output in an ipython notebook (other options later)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="796f14ee-2255-4b53-8a75-59221d7860b7">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# <hr/>
#
# ## Plotting.py
#
# This is a mid-level interface, used by the charting library (and other parts of bokeh).   It can also be used directly.
# The basic idea: there is an active plot, and you are modifying it.

# %%
import numpy as np
from bokeh.plotting import *
N = 1002
lin_arr = np.linspace(0, 4*np.pi, N)
sin_arr = np.sin(lin_arr)
cos_arr = np.cos(lin_arr)

# %% [markdown]
# <hr />
#
# ## Scatter Plots
#
# To begin with let's make a scatter plot.

# %%
p1 = figure()
p1.scatter(lin_arr, sin_arr, color="#FF00FF")
p1.scatter(lin_arr, cos_arr, color="green")
show(p1)
# Out:
#     <div class="plotdiv" id="fb01d75f-b739-4d22-b85c-6e9c5e036c8b"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fb01d75f-b739-4d22-b85c-6e9c5e036c8b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fb01d75f-b739-4d22-b85c-6e9c5e036c8b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b92104e7-25a7-4d66-92fb-63b301f08823":{"roots":{"references":[{"attributes":{},"id":"ef59294f-b3b2-49ba-b74f-a92152cf76ff","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"c593c03a-d90a-4bb7-98d3-376aa8383704","subtype":"Figure","type":"Plot"}},"id":"ad8347e2-0f20-4bc8-8e5b-aef50da97266","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"38cbf7c6-a3e9-4bd5-9f01-a30cd4915d9f","type":"Circle"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[10]</strong>&gt;</code></p>

# %% [markdown]
# <hr/>
#
# Let's play with colors now. Brewer is a popular set of palletes. Here we pick one and then build a vector of colors for the plot.

# %%
from bokeh.palettes import brewer
print("Brewer Palettes:", brewer.keys())
print("Brewer Grey Palettes:", brewer["Greys"].keys())
palette = brewer["Greys"][9] + list(reversed(brewer["Greys"][9]))
colors = palette * int(len(lin_arr) / len(palette)) + palette[0:len(lin_arr) % len(palette)]
# Out:
# Brewer Palettes: dict_keys(['YlOrBr', 'PiYG', 'Greys', 'YlGnBu', 'RdPu', 'BuPu', 'PuRd', 'PRGn', 'GnBu', 'PuBuGn', 'RdBu', 'Blues', 'PuOr', 'BuGn', 'RdYlGn', 'YlOrRd', 'Greens', 'Purples', 'RdGy', 'OrRd', 'Spectral', 'PuBu', 'BrBG', 'RdYlBu', 'Oranges', 'YlGn', 'Reds'])
# Brewer Grey Palettes: dict_keys([3, 4, 5, 6, 7, 8, 9])

# %%
p5 = figure()
p5.scatter(x=lin_arr, y=sin_arr, size=cos_arr**2*10 + 5, fill_color=colors)
show(p5)
# Out:
#     <div class="plotdiv" id="2fcacecf-1b8b-43da-8c24-b6e09adc4481"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2fcacecf-1b8b-43da-8c24-b6e09adc4481");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2fcacecf-1b8b-43da-8c24-b6e09adc4481' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"e87c5284-7eab-4520-bd2b-5091198d8f09":{"roots":{"references":[{"attributes":{},"id":"ef59294f-b3b2-49ba-b74f-a92152cf76ff","type":"BasicTickFormatter"},{"attributes":{},"id":"6ac699c3-b24e-4814-9747-ea4006aadacb","type":"BasicTicker"},{"attributes":{"formatter":{"id":"e9706a86-aa02-4584-b65c-b356985b022b","type":"BasicTickFormatter"},"plot":{"id":"b9f32b53-27bc-4a38-a859-f20dadd410eb","subtype":"Figure","type":"Plot"},"ticker":{"id":"77b752d7-512e-4738-bb60-d0e050300c33","type":"BasicTicker"}},"id":"89506e45-e770-468a-94b5-8984c5d224fd","type":"LinearAxis"},{"attributes":{"plot":{"id":"c593c03a-d90a-4bb7-98d3-376aa8383704","subtype":"Figure","type":"Plot"}},"id":"6070d5bf-2167-4c43-997f-ffd2a5834155","type":"ResetTool"},{"attributes":{"plot":{"id":"c593c03a-d90a-4bb7-98d3-376aa8383704","subtype":"Figure","type":"Plot"}},"id":"5fed1b02-ab2f-4f9f-ab18-c04dec52e6c1","type":"PreviewSaveTool"},{"attributes":{},"id":"da5a1622-363b-496a-9ff3-256d42e3c451","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0b7c01d6-9ed6-46da-a756-89cf80dc5d6e","subtype":"Figure","type":"Plot"}},"id":"63957742-2572-45ea-9555-41835e0a251f","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d6df0070-d243-4e11-8138-cee7d90685c0","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"4bd68e0d-8b77-4463-9699-a14451b03705","subtype":"Figure","type":"Plot"},"ticker":{"id":"a2cb7992-981b-4434-b291-f31f70ec1410","type":"BasicTicker"}},"id":"c6824db0-2d39-47ce-a872-b4eddd932fff","type":"Grid"},{"attributes":{"plot":{"id":"0b7c01d6-9ed6-46da-a756-89cf80dc5d6e","subtype":"Figure","type":"Plot"}},"id":"8a9e2a13-89aa-4668-a120-280409399aeb","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"3ff56442-10ff-4c57-97c8-04ec90a15093","type":"ColumnDataSource"},"glyph":{"id":"9d96789a-1a42-4179-b06f-0cbd3b6c5dcc","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"4cbdb655-1985-456c-b2af-57952ff298bc","type":"Circle"},"selection_glyph":null},"id":"c18a9130-78dd-4caa-94b9-3ad776a1d94e","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"307e8634-7c8d-4e10-9dd3-191de44f8415","type":"DataRange1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"158c7827-8a15-46a5-9bd5-6daf4dec8f6c","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"9580223e-b82b-4110-a2a6-6380d8ff4a36","type":"DataRange1d"},{"attributes":{"fill_color":{"value":"#FF00FF"},"line_color":{"value":"#FF00FF"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8119a422-0c1f-443e-8414-ae6e52c1a049","type":"Circle"},{"attributes":{"plot":{"id":"9424cee4-aaf0-4dba-aa59-50b9bee720a3","subtype":"Figure","type":"Plot"}},"id":"60210b9b-5884-44a5-835b-1b0d9a2c62bb","type":"PreviewSaveTool"},{"attributes":{"dimension":1,"plot":{"id":"76983dea-0548-4ebc-b775-063fd6f251ae","subtype":"Figure","type":"Plot"},"ticker":{"id":"b1143a87-749b-4c34-9b17-78028f1e74b4","type":"BasicTicker"}},"id":"da26eee8-9e24-4ab5-9a94-e8b43c0bc1cb","type":"Grid"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2db93502-3d40-46a7-85ad-229d76783ff5","type":"Circle"},{"attributes":{"plot":{"id":"c593c03a-d90a-4bb7-98d3-376aa8383704","subtype":"Figure","type":"Plot"}},"id":"1137e896-a72b-438b-8169-1b568e7cc229","type":"HelpTool"},{"attributes":{"callback":null},"id":"1c9a01b1-3e8b-495c-b356-c5770bb9d7d4","type":"DataRange1d"},{"attributes":{"formatter":{"id":"78ba4a1f-32a0-4b78-9bf4-5457a0cdf1b1","type":"BasicTickFormatter"},"plot":{"id":"4bd68e0d-8 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>

# %% [markdown]
# <hr/>
#
# ## Tools
#
# If you notice the bar at the top of the you see several places to interact with the plot.
#
# These are tools and there a many different tools built into the Bokeh.
#
# Let's take a look at HoverTools, but first we use Bokeh's data source which watches changes.

# %%
source = ColumnDataSource(
    data=dict(
        x=lin_arr,
        y=sin_arr,
        size=cos_arr**2*10 + 5,
        colors=colors
    )
)

# %%
from bokeh.models import HoverTool
from collections import OrderedDict

TOOLS="crosshair,pan,wheel_zoom,box_zoom,reset,hover,previewsave"
p6 = figure(title="Hoverful Scatter", tools=TOOLS)
p6.circle(x="x", y="y", size="size", source=source,
    fill_color="colors", fill_alpha=0.6, line_color=None)

hover = p6.select(dict(type=HoverTool))
hover.tooltips = OrderedDict([
    ("index", "$index"),
    ("(x,y)", "(@x, @y)"),
    ("size", "@size"),
    ("fill color", "$color[hex, swatch]:fill_color"),
])
show(p6)
# Out:
#     <div class="plotdiv" id="78054099-9a53-4685-8e54-0c3fff177182"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("78054099-9a53-4685-8e54-0c3fff177182");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '78054099-9a53-4685-8e54-0c3fff177182' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4eaa218e-4a1f-4b7d-acc2-3a7860a02468":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2955d35b-06e8-4ce3-8255-4e7402b08af1","type":"Circle"},{"attributes":{"plot":{"id":"cebe2cbf-8d74-42e7-a36d-fb543fec63c0","subtype":"Figure","type":"Plot"}},"id":"ef6eae7a-0f2e-47b1-b34d-510bc25fa60b","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,0.12441951103325913,0.24883902206651826,0.3732585330997774,0.4976780441330365,0.6220975551662956,0.7465170661995548,0.8709365772328139,0.995356088266073,1.1197755992993321,1.2441951103325912,1.3686146213658503,1.4930341323991096,1.6174536434323687,1.7418731544656278,1.866292665498887,1.990712176532146,2.1151316875654054,2.2395511985986643,2.3639707096319236,2.4883902206651825,2.6128097316984418,2.7372292427317007,2.86164875376496,2.9860682647982193,3.110487775831478,3.2349072868647375,3.3593267978979964,3.4837463089312557,3.6081658199645146,3.732585330997774,3.8570048420310328,3.981424353064292,4.105843864097551,4.230263
.9763894205636071,-0.9420342634699892,-0.8931150161867918,-0.8303879827647976,-0.7548229391532573,-0.6675881402161539,-0.5700322582137832,-0.4636635319853273,-0.3501264491913909,-0.2311763221149701,-0.10865215008547527,0.015551811920350768,0.13951533894392265,0.2613219232128601,0.37908840384037934,0.490994080973322,0.5953088642766655,0.6904200205717462,0.7748571071028897,0.8473147049577773,0.9066726011770723,0.9520131075327298,0.9826352482222637,0.9980655971335943,0.9980655971335944,0.9826352482222638,0.95201310753273,0.9066726011770728,0.847314704957778,0.77485710710289,0.6904200205717472,0.5953088642766667,0.4909940809733224,0.37908840384037984,0.2613219232128614,0.13951533894392404,0.015551811920351257,-0.1086521500854739,-0.23117632211496963,-0.3501264491913896,-0.46366353198532684,-0.5700322582137828,-0.6675881402161528,-0.7548229391532567,-0.8303879827647966,-0.8931150161867911,-0.942034263469989,-0.9763894205636067,-0.9956493479690185,-0.9995162822919881,-0.9879304397407569,-0.9610709403987248,-0.9193530389822364,-0.8634217048966641,-0.79414165084 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>

# %% [markdown]
# <hr />
#
# ## Basic interactivity
#
# Bokeh lets you use a Python update function to update your plots.
#
# In IPython notebook we can use the interactive widgets provided by the notebook. One can also use Flask or Bokeh-server to embed in outside the notebook.

# %%
x = np.linspace(0, 2*np.pi, 2000)
y = np.sin(x)

source = ColumnDataSource(data=dict(x=x, y=y))

p = figure(title="simple line example", plot_height=300, plot_width=600)
p.line(x, y, color="#2222aa", line_width=3, source=source, name="foo")

# %%
from IPython.html.widgets import interact
@interact(f=["sin", "cos", "tan"], w=(0,100), A=(1,10), phi=(0, 10, 0.1))
def update(f, w=1, A=1, phi=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    elif f == "tan": func = np.tan
    source.data['y'] = A * func(w * x + phi)
    source.push_notebook()
# Out:
# /Users/cdoig/anaconda/envs/py101/lib/python3.4/site-packages/ipykernel/__main__.py:8: BokehDeprecationWarning: bokeh.models.sources.push_notebook was deprecated in Bokeh 0.11.0; please use bokeh.io.push_notebook instead

# %%
show(p)
# Out:
#     <div class="plotdiv" id="cd5e95cb-002d-44a1-95ce-9dac783b0afd"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd5e95cb-002d-44a1-95ce-9dac783b0afd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd5e95cb-002d-44a1-95ce-9dac783b0afd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"1b2ecf20-dbc0-4d09-a525-81b873cc6ccb":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"size":{"field":"size","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2955d35b-06e8-4ce3-8255-4e7402b08af1","type":"Circle"},{"attributes":{"plot":{"id":"a8872c99-675b-4f09-be59-e20853a34658","subtype":"Figure","type":"Plot"}},"id":"999ae0f0-15fb-453f-b72a-9791766b9c42","type":"HelpTool"},{"attributes":{},"id":"709de5f5-79b2-43cc-95be-a77a4fe60fd2","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,0.12441951103325913,0.24883902206651826,0.3732585330997774,0.4976780441330365,0.6220975551662956,0.7465170661995548,0.8709365772328139,0.995356088266073,1.1197755992993321,1.2441951103325912,1.3686146213658503,1.4930341323991096,1.6174536434323687,1.7418731544656278,1.866292665498887,1.990712176532146,2.1151316875654054,2.2395511985986643,2.3639707096319236,2.4883902206651825,2.6128097316984418,2.7372292427317007,2.86164875376
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[15]</strong>&gt;</code></p>

# %% [markdown]
# <hr/>
#
# ## [bokeh.charts](http://bokeh.pydata.org/docs/user_guide/charts.html)
# Common Schemas for common tasks (and parameters).
#
# Expects data to be formatted as either an OrderedDict or a pandas dataframe.
#
# Supported Schemas: Bar, Boxplot, Categorical Heatmap, Histogram, Scatter, Timeseries

# %%
from collections import OrderedDict
from bokeh.charts import Histogram
from bokeh.io import show

mu, sigma = 0, 0.5
normal_dist = OrderedDict(normal=np.random.normal(mu, sigma, size=1000))
hist = Histogram(normal_dist, bins=50,
                 title="kwargs, dict_input", 
                 ylabel="frequency", 
                 width=400, 
                 height=350)

# %%
show(hist)
# Out:
#     <div class="plotdiv" id="d8b2f033-fb89-49e5-8d36-42b3088eb588"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d8b2f033-fb89-49e5-8d36-42b3088eb588");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd8b2f033-fb89-49e5-8d36-42b3088eb588' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"0740047e-9c5b-4868-9ef1-87eccae6cfc9":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"76983dea-0548-4ebc-b775-063fd6f251ae","subtype":"Figure","type":"Plot"},"ticker":{"id":"b1143a87-749b-4c34-9b17-78028f1e74b4","type":"BasicTicker"}},"id":"da26eee8-9e24-4ab5-9a94-e8b43c0bc1cb","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3795580b-46d0-4bb1-82ec-c432c11030df","type":"Rect"},{"attributes":{"callback":null,"column_names":["fill_alpha","line_color","y","width","color","height","x","line_alpha"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[54.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.07000000000000028],"x":["-0.05449999999999999"],"y":[27.0]}},"id":"68862839-60ea-49b9-942f-19caeb73afb7","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"48fe8850-e4a1-4fa7-bd0d-9badb35c2294","type":"Rect"},{"attributes":{"plot":{"id":"c593c03a-d90a-4bb7-98d3-376aa8383704","subtype":"Figure","type":"Plot"}},"id":"6070d5bf-2167-4c43-997f-ffd2a5834155","type":"ResetTool"},{"attributes":{"data_source":{"id":"70d25ea2-f9e0-4b48-a8ea-925bceec3252","type":"ColumnDataSource"},"glyph":{"id":"1c082b5a-3112-4491-b5fd-07d76d257f45","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2d238d50-06e1-456a-8654-4eb3c323ca55","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"c593c03a-d90a-4bb7-98d3-376aa8383704","subtype":"Figure","type":"Plot"}},"id":"5fed1b02-ab2f-4f9f-ab18-c04dec52e6c1","type":"PreviewSaveTool"},{"attributes":{"data_source":{"id":"7aed341a-7f9e-4dd5-8d69-024e51801598","type":"ColumnDataSource"},"glyph":{"id":"af063cba-11ab-4360-ad73-5aeaf61dcf9f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"daf1dae6-41b1-44d4-9c5d-524a7bb85121","type":"GlyphRenderer"},{"attributes":{},"id":"da5a1622-363b-496a-9ff3-256d42e3c451","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["fill_alpha","line_color","y","width","color","height","x","line_alpha"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[49.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.07000000000000028],"x":["0.33999999999999997"],"y":[24.5]}},"id":"41056a18-4710-4b05-ba25-23076cc03ead","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["fill_alpha","line_color","y","width","color","height","x","line_alpha"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.07000000000000028],"x":["-1.2349999999999999"],"y":[1.0]}},"id":"ca840d8b-bbf5-4380-8c5e-2c8f507ee855","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["fill_alpha","line_color","y","width","color","height","x","line_alpha"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.07000000000000028],"x":["1.52"],"y":[0.0]}},"id":"d6e2dc93-6ca7-4b8e-9291-61c4cc4a2e5e","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"9580223e-b82b-4110-a2a6-6380d8ff4a36","type":"DataRange1d"},{"attributes":{"data_source":{"id":"9ee08519-39d4-46d9-8d1f-2cecc8ffbda2","type":"ColumnDataSource"},"glyph":{"id":"fccd3562-4130-4976-8d63-86786545867e","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d24ce125-b6e3-4de4-bf65-bb04a0081f2a","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"fcbc8694-62a2-45d8-8c7e-e7d5b7e971e7"," ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[14]</strong>&gt;</code></p>
